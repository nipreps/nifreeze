# %% [markdown]
# # Single-shell HARDI (ds000114)
#
# Predicted diffusion volumes for the **single-shell** dataset `ds000114`, across the
# applicable models in both **LOVO** (leave-one-volume-out, holding out the
# predicted orientation) and **single-fit** (fit once on all volumes) modes.
#
# The coverage table lists every model × mode combination; inapplicable ones are
# marked with the reason they were skipped (a model's *capability contract*). Each
# run below is produced by the shared gallery harness, which is the
# single source of truth for the whole gallery.

# %%
from gallery.notebook import show_dataset

_ = show_dataset("ds000114")
